# %%
# 基本ライブラリ
import pandas as pd
import pandas.io.sql as psql
import numpy as np
import numpy.random as rd
import gc
import multiprocessing as mp
import os
import sys
import pickle
from collections import defaultdict
from glob import glob
import math
from datetime import datetime as dt
from pathlib import Path
import scipy.stats as st
import re
import shutil
from tqdm import tqdm_notebook as tqdm
import datetime
ts_conv = np.vectorize(datetime.datetime.fromtimestamp) # 秒ut(10桁) ⇒ 日付

# グラフ描画系
import matplotlib
from matplotlib import font_manager
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import rc

from matplotlib import animation as ani
from IPython.display import Image

plt.rcParams["patch.force_edgecolor"] = True
#rc('text', usetex=True)
from IPython.display import display # Allows the use of display() for DataFrames
import seaborn as sns
sns.set(style="whitegrid", palette="muted", color_codes=True)
sns.set_style("whitegrid", {'grid.linestyle': '--'})
red = sns.xkcd_rgb["light red"]
green = sns.xkcd_rgb["medium green"]
blue = sns.xkcd_rgb["denim blue"]

#カラム内の文字数。デフォルトは50
pd.set_option("display.max_colwidth", 100)

#行数
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
#
pd.options.display.float_format = '{:,.5f}'.format

# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold

from sklearn import metrics
import json

import warnings
warnings.filterwarnings("ignore")


sys.path.append('..')
from lib.line_notif import send_message
#from lib.utils import matrics_rotate
from lib.utils import reduce_mem_usage, current_time, unpickle, to_pickle
from lib.utils import one_hot_encoder, apply_agg, multi_combine_categorical_feature
from lib.utils import import_data, get_split_indexer

# %%
def group_mean_log_mae(y_true, y_pred, types, floor=1e-9):
    """
    Fast metric computation for this competition: https://www.kaggle.com/c/champs-scalar-coupling
    Code is from this kernel: https://www.kaggle.com/uberkinder/efficient-metric
    """
    maes = (y_true - y_pred).abs().groupby(types).mean()
    return np.log(maes.map(lambda x: max(x, floor))).mean()

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
structures = pd.read_csv('../input/structures.csv')

# %%
test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC

# %%
test_id = test.id.values

# %%
ls -l ../submit/v003_050/
# Out:
# total 624904
# drwxr-xr-x  5 kenichi.matsui  DENA\Domain Users       160  7  8 02:21 _old/
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67160551  7  8 02:55 blending_v003_050_3seeds.csv
# -rw-r--r--@ 1 kenichi.matsui  DENA\Domain Users  67161305  7  8 02:21 submission_t_v003_050_40.csv
# -rw-r--r--@ 1 kenichi.matsui  DENA\Domain Users  67160520  7  8 02:22 submission_t_v003_050_41.csv
# -rw-r--r--@ 1 kenichi.matsui  DENA\Domain Users  67161640  7  8 02:51 submission_t_v003_050_42.csv

# %%
sub_list = []
trial_list = ["024", "031", "036", "050", "051"]
coeflist = [1, 1, 3, 4, 4]
coef_sum = 0
for trial_no, coef in zip(trial_list, coeflist):
    print(f"trial_no: {trial_no}")
    files = np.sort(glob(f"../submit/v003_{trial_no}/submission_t_v003_{trial_no}_*.csv")).tolist()
    #sub_files += files
    for f in tqdm(files):
        sub_df = pd.read_csv(f, index_col=0).loc[test_id]
        sub_df.scalar_coupling_constant *= coef
        sub_list += [sub_df]
        coef_sum += coef
        
len(sub_list)
# Out:
# trial_no: 024
# ...
# trial_no: 031
# ...
# trial_no: 036
# ...
# trial_no: 050
# ...
# trial_no: 051
# ...
# 63

# %%
np.dot([24, 12, 22, 3, 2],  [1, 1, 3, 4, 4])
# Out:
# 122

# %%
len(sub_list), coef_sum
# Out:
# (183, 122)

# %%
submit_list_df = pd.concat(sub_list, axis=1)
submit_list_df["mean_score"] = submit_list_df.sum(axis=1).values / coef_sum

# %%
submit_df = submit_list_df[["mean_score"]]
submit_df.columns = ["scalar_coupling_constant"]

# %%
submit_df.head()
# Out:
#          scalar_coupling_constant
# id
# 4658147                  16.88135
# 4658148                 188.12702
# 4658149                   1.70096
# 4658150                 186.66830
# 4658151                  13.03875

# %%
Path("../submit/ensemble").mkdir(parents=True, exist_ok=True)

# %%
submit_df.to_csv(f'../submit/ensemble/blending_v003_{"-".join(trial_list)}_{len(sub_files)}seeds_weighted.csv', index=True)

# %%
ls -ltr ../submit/ensemble
# Out:
# total 1730168
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67160057  6 16 16:56 ensemble_v003_007__009_1vs2_.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67160057  6 16 16:57 ensemble_v003_009__015_2vs1.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67157799  6 16 19:29 ensemble_v003_009__015__016_3vs1vs1.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67158249  6 21 10:09 ensemble_v003_009__017__019_3vs1vs1.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67158249  6 21 10:09 ensemble_v003_009__017__019_1vs1.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67161117  6 21 16:33 ensemble_v003_017__019__021_2vs2vs1.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67160867  6 22 11:38 ensemble_v003_017__019__023__021__022.csv
# -rw-r--r--  1 kenichi.matsui  DENA\Domain Users  67160621  6 23 02:06 ensemble_v003_017__019__023__021__022_1vs1vs1vs4.csv
# ...

# %%
# !head ../submit/ensemble/blending_v003_024-031-036-050-051_63seeds_weighted.csv
# Out:
# id,scalar_coupling_constant
# 4658147,16.88135146721076
# 4658148,188.12702352386572
# 4658149,1.7009609401536254
# 4658150,186.6683023338314
# 4658151,13.038752435165513
# 4658152,89.79070025402932
# 4658153,2.344809836208963
# 4658154,-7.22039365501432
# 4658155,-9.43024411283681

# %%
# !head ../submit/ensemble/blending_v003_024-031-036-050-051_63seeds.csv
# Out:
# id,scalar_coupling_constant
# 4658147,16.289544145644545
# 4658148,187.0198328659281
# 4658149,1.7995445650165995
# 4658150,185.79522022802735
# 4658151,12.167132232503974
# 4658152,89.7054603101084
# 4658153,2.308083678314555
# 4658154,-7.206845206160427
# 4658155,-9.417233137838183

# %%
# !head ../submit/v003_050/blending_v003_050_3seeds.csv
# Out:
# id,scalar_coupling_constant
# 4658147,17.1847154908295
# 4658148,184.0664257872054
# 4658149,2.6265957885323488
# 4658150,182.84038246330132
# 4658151,14.938255101642035
# 4658152,90.06841816892563
# 4658153,2.345229644859062
# 4658154,-7.197686768425346
# 4658155,-9.428125416483352

# %%
# !head ../submit/v003_036/blending_v003_036_14seeds.csv
# Out:
# id,scalar_coupling_constant
# 4658147,17.664744777896082
# 4658148,190.45667304229232
# 4658149,1.478981086671752
# 4658150,188.5906710452791
# 4658151,14.026912088540234
# 4658152,89.8718425627837
# 4658153,2.430207733604394
# 4658154,-7.263924634816904
# 4658155,-9.46558916299235

# %%
# !head ../submit/v003_036/blending_v003_036_20seeds.csv
# Out:
# id,scalar_coupling_constant
# 4658147,17.677486608734476
# 4658148,190.49708756044666
# 4658149,1.4322411872907357
# 4658150,188.70633024479247
# 4658151,13.93892580736383
# 4658152,89.79609688171703
# 4658153,2.3961143585790707
# 4658154,-7.271904622191765
# 4658155,-9.459570896445538

# %%
# !head ../submit/v003_024/blending_v003_024_14seeds.csv
# Out:
# id,scalar_coupling_constant
# 4658147,14.353976423109984
# 4658148,183.10524217370786
# 4658149,1.737910916691683
# 4658150,182.44727676700177
# 4658151,10.11133708598861
# 4658152,89.58719008504241
# 4658153,2.242156641327718
# 4658154,-7.146588388196449
# 4658155,-9.350822712856004

# %%
ls -l ../submit/v003_050/
# Out:
# total 624904
# drwxr-xr-x  5 kenichi.matsui  1522739515       160  7  8 02:21 _old/
# -rw-r--r--  1 kenichi.matsui  1522739515  67160551  7  8 02:55 blending_v003_050_3seeds.csv
# -rw-r--r--@ 1 kenichi.matsui  1522739515  67161305  7  8 02:21 submission_t_v003_050_40.csv
# -rw-r--r--@ 1 kenichi.matsui  1522739515  67160520  7  8 02:22 submission_t_v003_050_41.csv
# -rw-r--r--@ 1 kenichi.matsui  1522739515  67161640  7  8 02:51 submission_t_v003_050_42.csv

# %%
# !kaggle competitions submit -c champs-scalar-coupling -f ../submit/ensemble/blending_v003_024-031-036-050-051_63seeds_weighted.csv -m "blending "024", "031", "036", "050", "051" 63 files. weighted 1, 1, 3, 4, 4"
# Out:
# 100%|██████████████████████████████████████| 64.1M/64.1M [00:09<00:00, 7.23MB/s]
# Successfully submitted to Predicting Molecular Properties

# %%
for i, d in submit_list_df.head().iterrows():
    d.hist()
    plt.show()

# %%
plt.figure(figsize=(25,5))
ax = plt.subplot(111)
cv_std.hist(ax=ax, bins=100)
plt.yscale("log")

# %%
cv_std = submit_list_df.std(axis=1)
cv_mean = submit_list_df.mean(axis=1)
cv_value = cv_std/cv_mean

# %%
plt.figure(figsize=(25,5))
ax = plt.subplot(111)
cv_value[np.abs(cv_value) < 500].hist(ax=ax, bins=100)
plt.yscale("log")

# %%
np.abs(cv_value).sort_values(ascending=False)[:10]
# Out:
# id
# 5412746   219,716.34590
# 5465807   126,850.04206
# 5546431    85,100.91446
# 6552445    60,056.74870
# 5436786    18,762.42936
# 6942259    16,531.30469
# 4989294    13,911.01801
# 6462400    10,928.18863
# 4993772    10,377.60660
# 6114912     9,173.00372
# dtype: float64

# %%
high_cv = cv_value[np.abs(cv_value) > 500]
high_cv
# Out:
# id
# 4698369     -6,946.80593
# 4710913        784.91746
# 4823283        918.63092
# 4825478      3,784.50219
# 4853540        576.83325
# 4882092       -623.90341
# 4892956      2,308.43802
# 4902768     -3,048.53894
# 4921967        633.81338
# 4935801        901.29538
# 4989294    -13,911.01801
# 4993772     10,377.60660
# 5085605     -2,476.27122
# 5098336        810.44443
# 5124395       -829.80919
# 5156635        595.45082
# 5169103     -6,183.53375
# 5181557      1,101.13801
# 5212243     -6,319.13448
# 5219726        734.34349
# 5241459      1,389.43887
# 5247798     -1,082.86622
# 5254630        556.98296
# 5263450        949.86269
# 5264679     -3,482.49522
# 5267715     -1,060.28821
# 5272631      1,867.69635
# 5307174      1,155.11992
# 5308095      4,925.84640
# 5335302      1,355.83248
# 5338066      2,875.03888
# 5397576      1,180.83817
# 5398959     -1,424.92753
# 5403209       -877.26486
# 5412746   -219,716.34590
# 5415657     -1,024.71457
# ...

# %%
submit_list_df_ = submit_list_df.copy()

# %%
submit_list_df_["std_score"] = submit_list_df_.std(axis=1)

# %%
submit_list_df_.loc[high_cv.index]
# Out:
#          scalar_coupling_constant  scalar_coupling_constant  \
# id
# 4698369                  -0.10891                   0.20726
# 4710913                   0.05207                   0.08899
# 4823283                  -0.11116                   0.22432
# 4825478                  -0.12516                   0.18095
# 4853540                  -0.15255                   0.10124
# 4882092                  -0.06139                   0.10911
# 4892956                   0.13003                  -0.04687
# 4902768                  -0.02569                  -0.00599
# 4921967                  -0.03500                  -0.04545
# 4935801                  -0.32719                  -0.00198
# 4989294                   0.35475                  -0.22554
# 4993772                  -0.36588                   0.44523
# 5085605                   0.07770                  -0.05150
# 5098336                   0.01516                   0.11695
# 5124395                   0.00263                  -0.05532
# ...

# %%
(cv_std>2).sum()
# Out:
# 164

# %%
submit_list_df_[cv_std>2]
# Out:
#          scalar_coupling_constant  scalar_coupling_constant  \
# id
# 4658147                  14.42941                  17.94441
# 4658148                 185.88040                 189.22815
# 4658150                 185.21704                 187.47601
# 4659320                  33.08035                  34.81430
# 4694991                 132.74731                 133.13240
# 4715174                 141.75089                 142.87002
# 4762582                  34.66631                  34.38711
# 4788766                 132.34788                 135.45968
# 4810197                  29.24068                  27.94773
# 4819406                  33.91710                  33.62866
# 4930173                  28.22540                  25.83043
# 5055211                  14.55677                   4.76096
# 5055218                  13.33331                  15.27559
# 5055280                  -1.02136                  -1.12415
# 5055399                  -1.21386                  -1.12960
# ...
