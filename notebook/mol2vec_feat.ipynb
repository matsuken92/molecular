# %%
# %%html
# <style type="text/css">
# .CodeMirror pre, .output pre { font-family: Consolas, Monaco, monospace; }
# .text_cell_render { font-family: Consolas, Monaco, monospace; }
# </style>
# Out:
# <style type="text/css">
# .CodeMirror pre, .output pre { font-family: Consolas, Monaco, monospace; }
# .text_cell_render { font-family: Consolas, Monaco, monospace; }
# </style>

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm_notebook as tqdm

from rdkit import Chem
from mol2vec.features import mol2alt_sentence
import pybel

from gensim.models import Word2Vec


def xyz_to_smiles(fname: str) -> str:
    mol = next(pybel.readfile("xyz", fname))
    smi = mol.write(format="smi")
    return smi.split()[0].strip()

file_dir = '../input/structures/'
mols_files=os.listdir(file_dir)
mols_index=dict(map(reversed,enumerate(mols_files)))
mol_name = list(mols_index.keys())

# %%
import sys
sys.path.append('..')
from lib.line_notif import send_message
from lib.utils import reduce_mem_usage, current_time, unpickle, to_pickle

# %%
mol_name = np.sort(mol_name)

# %%
import multiprocessing as mp
n_split = mp.cpu_count()
unit = np.ceil(len(mol_name) / n_split).astype(int)
indexer = [[unit * (i), unit * (i + 1)] for i in range(n_split)]

split_mol_names = []
for idx in indexer:
    split_mol_names.append(mol_name[idx[0]:idx[1]])

mp_data = [{"mol_names": m} for m in split_mol_names]

# %%
def xyz_to_smiles(data) -> str:
    ret_list = []
    for fname in data["mol_names"]:
        mol = next(pybel.readfile("xyz", file_dir+fname))
        smi = mol.write(format="smi")
        ret_list += [smi.split()[0].strip()]
    return ret_list
                                        
num_workers = mp.cpu_count()
with mp.Pool(num_workers) as executor:
    features_chunk = executor.map(xyz_to_smiles, mp_data)

# %%
features_chunk[0]
# Out:
# ['C',
#  'N',
#  'O',
#  'C#C',
#  'C#N',
#  'CC',
#  'CO',
#  'CC#C',
#  'CC#N',
#  'CC=O',
#  'NC=O',
#  'CCC',
#  'CCO',
#  'COC',
#  'C1CC1',
#  'C1CO1',
#  'CC(=O)C',
#  'CC(=O)N',
#  'NC(=O)N',
#  'CC(C)C',
#  'CC(C)O',
#  'C(#C)C#C',
#  'C(#C)C#N',
#  'O=CC#C',
#  'O=CC#N',
#  'O=CC=O',
#  'CC#CC',
#  'CCC#C',
#  'CCC#N',
#  'NCC#N',
#  'OCC#C',
#  'OCC#N',
#  'CCC=O',
#  'CNC=O',
#  'COC=O',
#  'OCC=O',
#  'CCCC',
#  'CCCO',
#  'CCOC',
#  'OCCO',
#  'CC1CC1',
#  'C[C@H]1CO1',
#  'CN1CC1',
#  'OC1CC1',
#  'C1CCC1',
#  'C1COC1',
#  'CC(=NO)C',
#  '[nH]1cccc1',
#  '[nH]1ccnc1',
#  'o1cccc1',
#  'o1ccnc1',
#  'CC(C)(C)C',
#  'CC(C)(C)O',
#  'CC(=O)C#C',
#  'CC(=O)C#N',
#  'NC(=O)C#C',
#  'CC(=O)C=O',
#  'NC(=O)C=O',
#  'CC(C)C#C',
#  'CC(C)C#N',
#  'C[C@@H](N)C#N',
#  'C[C@@H](O)C#C',
#  'C[C@@H](O)C#N',
#  'CC(C)C=O',
#  'C[C@@H](O)C=O',
#  'CN(C)C=O',
#  'CC(=O)CO',
#  'CCC(=O)C',
#  'CCC(=O)N',
#  'CNC(=O)C',
#  'CNC(=O)N',
#  'COC(=N)C',
#  'COC(=O)C',
#  'COC(=O)N',
#  'NC(=O)CO',
#  'CC(C)CO',
#  'C[C@@H](O)CO',
#  'CCC(C)C',
#  'CC[C@@H](C)O',
#  'COC(C)C',
#  'CC1(C)CC1',
#  'CC1(C)CO1',
#  'CC1(O)CC1',
#  'N=C1CCO1',
#  'O=C1CCC1',
#  'O=C1CCN1',
#  'O=C1CCO1',
#  'O=C1CNC1',
#  'O=C1COC1',
#  'CC1CCC1',
#  'C[C@H]1CCO1',
#  'CC1COC1',
#  'OC1CCC1',
#  'OC1COC1',
#  'C[C@H]1C[C@H]1C',
#  'C[C@H]1C[C@H]1O',
#  'C[C@H]1CN1C',
#  'C[C@H]1O[C@H]1C',
#  'O[C@H]1C[C@H]1O',
#  'C1[C@H]2C[C@@H]1C2',
#  'C1[C@H]2C[C@@H]1O2',
#  'C#CCC#C',
#  'C#CCC#N',
#  'N#CCC#N',
#  'O=CCC#C',
#  'O=CCC#N',
#  'N=CNC=O',
#  'N=COC=O',
#  'O=CNC=O',
#  'CC#CC#C',
#  'CC#CC#N',
#  'CC#CC=O',
#  'CC#CCO',
#  'CCC#CC',
#  'CO/C=N/C',
#  'CCCC#C',
#  'CCCC#N',
#  'CNCC#N',
#  'COCC#C',
#  'COCC#N',
#  'OCCC#C',
#  'OCCC#N',
#  'CCCC=O',
#  'CCNC=O',
#  'CCOC=O',
#  'COCC=O',
#  'OCCC=O',
#  'CCCCC',
#  'CCCCO',
#  'CCCOC',
#  'CCOCC',
#  'COCCO',
#  'OCCCO',
#  'C#CC1CC1',
#  'C#C[C@H]1CN1',
#  'C#C[C@H]1CO1',
#  'N#CC1CC1',
#  'N#C[C@H]1CN1',
#  'N#C[C@H]1CO1',
#  'O=CC1CC1',
#  'O=C[C@H]1CN1',
#  'O=C[C@H]1CO1',
#  'O=CN1CC1',
#  'CCC1CC1',
#  'CC[C@H]1CO1',
#  'CCN1CC1',
#  'COC1CC1',
#  'OCC1CC1',
#  'OC[C@H]1CN1',
#  'OC[C@H]1CO1',
#  'C1CC=CC1',
#  'C1CN=CO1',
#  'C1OCC=C1',
#  'C1CCCC1',
#  'C1CCOC1',
#  'C1COCO1',
#  'C1[C@H]2CC[C@@H]12',
#  'C1[C@H]2CO[C@@H]12',
#  'C1C[C@H]2O[C@@H]12',
#  '[nH]1cccn1',
#  '[nH]1ccnn1',
#  'N1[CH]N=C[N]1',
#  '[nH]1cnnc1',
#  '[nH]1nccn1',
#  'o1cccn1',
#  'o1ccnn1',
#  'O1C=[N]=C[N]1',
#  'o1cnnc1',
#  'o1cnnn1',
#  'o1nccn1',
#  'o1ncnn1',
#  'C/C(=N\\O)/C#C',
#  'C/C(=N\\O)/CO',
#  'CC/C(=N/O)/C',
#  'ON=C1CCC1',
#  'ON=C1CNC1',
#  'ON=C1COC1',
#  'O=c1[nH]cc[nH]1',
#  'O=c1[nH]cco1',
#  'O=c1occo1',
#  'Cc1ccc[nH]1',
#  'Cc1ccco1',
#  'Cc1cnco1',
#  'Cc1ncco1',
#  'Nc1ccc[nH]1',
#  'Nc1ccco1',
#  'Nc1cnco1',
#  'Nc1ncco1',
#  'Oc1ccc[nH]1',
#  'Oc1cnc[nH]1',
#  'Oc1ncc[nH]1',
#  'Cc1c[nH]cc1',
#  'Cc1c[nH]cn1',
#  'Cc1cocc1',
#  'Cc1cocn1',
#  'Nc1c[nH]cc1',
#  'Nc1c[nH]cn1',
#  'Nc1cocc1',
#  'Nc1cocn1',
#  'Oc1c[nH]cc1',
#  'OC1=N[CH]N[CH]1',
#  'OC1=[N]=CO[CH]1',
#  'Cn1cccc1',
#  'Cn1ccnc1',
#  'c1ccccc1',
#  'c1ccncc1',
#  'c1cnccn1',
#  'c1cncnc1',
#  'C1=[N]=CN=C[N]1',
#  'CC(C)(C)C#C',
#  'CC(C)(C)C#N',
#  'CC(C)(N)C#N',
#  'CC(C)(O)C#C',
#  'CC(C)(O)C#N',
#  'CC(C)(C)C=O',
#  'CC(C)(O)C=O',
#  'CC(C)(C)CO',
#  'CC(C)(O)CO',
#  'CCC(C)(C)C',
#  'CCC(C)(C)O',
#  'COC(C)(C)C',
#  'CC#CC(=O)C',
#  'CC#CC(=O)N',
#  'CC#CC(C)C',
#  'CC#C[C@@H](C)O',
#  'CC(=O)CC#C',
#  'CC(=O)CC#N',
#  'NC(=O)CC#C',
#  'NC(=O)CC#N',
#  'CC(=N)NC=O',
#  'CC(=N)OC=O',
#  'CC(=O)CC=O',
#  'CC(=O)NC=N',
#  'CC(=O)NC=O',
#  'CC(=O)OC=N',
#  'NC(=O)CC=O',
#  'NC(=O)NC=N',
#  'NC(=O)NC=O',
#  'NC(=O)OC=N',
#  'CC(C)CC#C',
#  'CC(C)CC#N',
#  'C[C@@H](O)CC#C',
#  'C[C@@H](O)CC#N',
#  'CN(C)CC#N',
#  'CC(C)CC=O',
#  'CC(C)NC=O',
#  'CC(C)OC=O',
#  'C[C@@H](O)CC=O',
#  'CN(C)CC=O',
#  'CC(=O)CCO',
#  'CCCC(=O)C',
#  'CCCC(=O)N',
#  'CCNC(=O)C',
#  'CCNC(=O)N',
#  'CCOC(=O)C',
#  'CCOC(=O)N',
#  'COCC(=O)C',
#  'COCC(=O)N',
#  'NC(=O)CCO',
#  '[NH3]CCC(=O)[O]',
#  'CC(C)CCO',
#  'C[C@@H](O)CCO',
#  'CCCC(C)C',
#  'CCC[C@@H](C)O',
#  'CCOC(C)C',
#  'COCC(C)C',
#  'COC[C@@H](C)O',
#  'CC(=O)C(=O)C',
#  'CC(=O)C(=O)N',
#  'NC(=[NH2])C(=O)[O]',
#  'NC(=O)C(=O)N',
#  'CC(C)C(=O)C',
#  'CC(C)C(=O)N',
#  'C[C@@H](O)C(=O)C',
#  'C[C@@H](O)C(=O)N',
#  'CN(C)C(=O)C',
#  'CN(C)C(=O)N',
#  'CC(C)C(C)C',
#  'CC(C)[C@@H](C)O',
#  'C[C@@H](O)[C@@H](C)O',
#  'CC1(C)CCC1',
#  'CC1(C)CCO1',
#  'CC1(C)COC1',
#  'CC1(O)CCC1',
#  'CC1(O)COC1',
#  'CC1(C)C[C@H]1O',
#  'C[C@@]1(O)C[C@H]1O',
#  'C[C@H]1CC1(C)C',
#  'C[C@H]1C[C@]1(C)O',
#  'C[C@H]1OC1(C)C',
#  'CN1CC1(C)C',
#  'C[C@H]1CC(=N)O1',
#  'CC1CC(=O)C1',
#  'C[C@H]1CC(=O)N1',
#  'C[C@H]1CC(=O)O1',
#  'CN1CC(=O)C1',
#  'OC1CC(=O)C1',
#  'C[C@H]1C[C@@H](C)C1',
#  'C[C@H]1C[C@@H](C)O1',
#  'C[C@H]1C[C@@H](O)C1',
#  'CN1CC(O)C1',
#  'O[C@H]1C[C@@H](O)C1',
#  'C[C@@]12C[C@@H](C1)C2',
#  'C[C@@]12C[C@@H](C1)O2',
#  'C[C@@]12CN(C1)C2',
#  'O[C@@]12C[C@@H](C1)C2',
#  'O[C@@]12CN(C1)C2',
#  'O=C(C#C)C#C',
#  'O=C(C#C)C#N',
#  'O=CC(=O)C#C',
#  'O=CC(=O)C#N',
#  'O=CC(=O)C=O',
#  'CC(C#C)C#C',
#  'C[C@@H](C#C)C#N',
#  'CC(C#N)C#N',
#  'N[C@@H](C#C)C#N',
#  'NC(C#N)C#N',
#  'OC(C#C)C#C',
#  'O[C@@H](C#C)C#N',
#  'OC(C#N)C#N',
#  'C[C@@H](C=O)C#C',
#  'C[C@@H](C=O)C#N',
#  'O[C@@H](C=O)C#C',
#  'O[C@@H](C=O)C#N',
#  'CC(C=O)C=O',
#  'CN(C=N)C=O',
#  'CN(C=O)C=O',
#  'OC(C=O)C=O',
#  'C/N=C(\\N)/C#N',
#  'C/N=C(\\N)/C=O',
#  'CCC(=O)C#C',
#  'CCC(=O)C#N',
#  'CNC(=N)C#N',
#  'CNC(=O)C#C',
#  'COC(=O)C#C',
#  'COC(=O)C#N',
#  'OCC(=O)C#C',
#  'OCC(=O)C#N',
#  'CCC(=O)C=O',
#  'CNC(=N)C=O',
#  'CNC(=O)C=O',
#  'COC(=O)C=O',
#  'OCC(=O)C=O',
#  'CCC(=O)CC',
#  'CCC(=O)CO',
#  'CCC(=O)NC',
#  'CCC(=O)OC',
#  'CNC(=O)CO',
#  'CNC(=O)NC',
#  'CNC(=O)OC',
#  'COC(=O)CN',
#  'COC(=O)CO',
#  'OCC(=O)CO',
#  'CO/C(=N/C)/C',
#  'C[C@@H](CO)C#C',
#  'C[C@@H](CO)C#N',
#  'CC[C@@H](C)C#C',
#  'CC[C@@H](C)C#N',
#  'CC[C@@H](N)C#N',
#  'CC[C@@H](O)C#C',
#  'CC[C@@H](O)C#N',
#  'CN[C@@H](C)C#N',
#  'CO[C@@H](C)C#C',
#  'CO[C@@H](C)C#N',
#  'N[C@@H](CO)C#N',
#  'NC[C@@H](N)C#N',
#  'NC[C@@H](O)C#N',
#  'OC[C@@H](O)C#C',
#  'OC[C@@H](O)C#N',
#  'C[C@@H](CO)C=O',
#  'CC[C@@H](C)C=O',
#  'CC[C@@H](O)C=O',
#  'CCN(C)C=O',
#  'CO[C@@H](C)C=O',
#  'OC[C@@H](O)C=O',
#  'CC(CO)CO',
#  'CCC(C)CC',
#  'CC[C@@H](C)CO',
#  'CC[C@@H](C)OC',
#  'CCC(O)CC',
#  'CC[C@@H](O)CO',
#  'CO[C@@H](C)CO',
#  'OCC(O)CO',
#  'CC1(CC1)C#C',
#  'CC1(CC1)C#N',
#  'C[C@]1(CN1)C#C',
#  'C[C@]1(CN1)C#N',
#  'C[C@]1(CO1)C#C',
#  'C[C@]1(CO1)C#N',
#  'NC1(CC1)C#N',
#  'OC1(CC1)C#C',
#  'OC1(CC1)C#N',
#  'CC1(CC1)C=O',
#  'C[C@]1(CN1)C=O',
#  'C[C@]1(CO1)C=O',
#  'OC1(CC1)C=O',
#  'CC1(CO)CC1',
#  'C[C@@]1(CO)CN1',
#  'C[C@@]1(CO)CO1',
#  'CCC1(C)CC1',
#  'CC[C@@]1(C)CO1',
#  'CCC1(O)CC1',
#  'COC1(C)CC1',
#  'OCC1(O)CC1',
#  'C[C@H]1CCC1=O',
#  'C[C@H]1CNC1=O',
#  'C[C@H]1COC1=N',
#  'C[C@H]1COC1=O',
#  'C[C@H]1NCC1=O',
#  'C[C@H]1OCC1=O',
#  'CN1CCC1=O',
#  'N[C@H]1COC1=N',
#  'N[C@H]1COC1=O',
#  'O[C@H]1CCC1=O',
#  'O[C@H]1CNC1=O',
#  'O[C@H]1COC1=N',
#  'O[C@H]1COC1=O',
#  'C[C@H]1CC[C@H]1C',
#  'C[C@H]1CC[C@H]1O',
#  'C[C@H]1CO[C@H]1C',
#  'C[C@H]1OC[C@H]1O',
#  'O[C@H]1CC[C@H]1O',
#  'N=C1CN=CN1',
#  'O=C1CC=CC1',
#  'O=C1CC=CN1',
#  'O=C1CN=CN1',
#  'O=C1CN=CO1',
#  'N=C1OCC=C1',
#  'O=C1CCC=C1',
#  'O=C1NCC=C1',
#  'N=C1CCCO1',
#  'N=C1COCO1',
#  'N=C1OCCO1',
#  'O=C1CCCC1',
#  'O=C1CCCN1',
#  'O=C1CCCO1',
#  'O=C1CCOC1',
#  'O=C1COCO1',
#  'O=C1NCCN1',
#  'O=C1NCCO1',
#  'O=C1OCCO1',
#  'CC1=CCCC1',
#  'CC1=CCOC1',
#  'CC1=NCCO1',
#  'C[C@H]1CC=CC1',
#  'C[C@H]1CN=CO1',
#  'O[C@H]1CC=CC1',
#  'C[C@H]1CCC=C1',
#  'C[C@H]1COC=N1',
#  'C[C@H]1OCC=C1',
#  'O[C@H]1CCC=C1',
#  'CC1CCCC1',
#  'C[C@H]1CCCO1',
#  'C[C@H]1CCOC1',
#  'C[C@H]1COCO1',
#  'CC1OCCO1',
#  'OC1CCCC1',
#  'O[C@H]1CCOC1',
#  'C[C@H]1[C@@H](C)[C@H]1C',
#  'C[C@H]1[C@@H](C)[C@H]1O',
#  'C[C@H]1[C@@H](C)N1C',
#  'C[C@H]1[C@@H](O)[C@H]1O',
#  'O[C@H]1[C@@H](O)[C@H]1O',
#  'C[C@]12C[C@H]1CC2',
#  'C[C@]12C[C@H]1CO2',
#  'C[C@]12C[C@H]1OC2',
#  'C[C@]12CC[C@H]1O2',
#  'O[C@]12C[C@H]1CC2',
#  'O[C@]12C[C@H]1OC2',
#  'C#CC#CC#C',
#  'C#CC#CC#N',
#  'C#CCCC#C',
#  'C#CCCC#N',
#  'N#CCCC#N',
#  'O=CC#CC#C',
#  'O=CC#CC#N',
#  'O=CC#CC=O',
#  'N=COCC#C',
#  'N=COCC#N',
#  'O=CCCC#C',
#  'O=CCCC#N',
#  'O=CNCC#C',
#  'O=CNCC#N',
#  'O=COCC#C',
#  'O=COCC#N',
#  'N=COCC=O',
#  'O=CCCC=O',
#  'O=CCNC=O',
#  'O=CCOC=O',
#  'CC#CC#CC',
#  'CC#CCC#C',
#  'CC#CCC#N',
#  'CC#CCC=O',
#  'C/N=C/NC=O',
#  'C/N=C/OC=O',
#  'CCC#CC#C',
#  'CCC#CC#N',
#  'OCC#CC#C',
#  'OCC#CC#N',
#  'CCC#CC=O',
#  'OCC#CC=O',
#  'CCC#CCC',
#  'CCC#CCO',
#  'OCC#CCO',
#  'CC/N=C/OC',
#  'CC#CCCO',
#  'CCCC#CC',
#  'COCC#CC',
#  'CCO/C=N/C',
#  'CCCCC#C',
#  'CCCCC#N',
#  'CCNCC#N',
#  'CCOCC#C',
#  'CCOCC#N',
#  'COCCC#C',
#  'COCCC#N',
#  'OCCCC#C',
#  'OCCCC#N',
#  'CCCCC=O',
#  'CCCNC=O',
#  'CCCOC=O',
#  'CCOCC=O',
#  'COCCC=O',
#  'OCCCC=O',
#  'OCCNC=O',
#  'OCCOC=N',
#  'OCCOC=O',
#  'CCCCCC',
#  'CCCCCO',
#  'CCCCOC',
#  'CCCOCC',
#  'CCOCCO',
#  'COCCCO',
#  'COCCOC',
#  'OCCCCO',
#  'C#CC1CCC1',
#  'C#C[C@H]1CCO1',
#  'C#CC1COC1',
#  'N#CC1CCC1',
#  'N#C[C@H]1CCN1',
#  'N#C[C@H]1CCO1',
#  'N#CC1COC1',
#  'O=CC1CCC1',
#  'O=C[C@H]1CCO1',
#  'O=CC1COC1',
#  'O=CN1CCC1',
#  'C/N=C\\1/CCO1',
#  'CCC1CCC1',
#  'CC[C@H]1CCO1',
#  'CCC1COC1',
#  'COC1CCC1',
#  'COC1COC1',
#  'OCC1CCC1',
#  'OC[C@H]1CCO1',
#  'OCC1COC1',
#  'C#CCC1CC1',
#  'C#CC[C@H]1CO1',
#  'C#CCN1CC1',
#  'N#CCC1CC1',
#  'N#CC[C@H]1CN1',
#  'N#CC[C@H]1CO1',
#  'N#CCN1CC1',
#  'N=COC1CC1',
#  'O=CCC1CC1',
#  'O=CC[C@H]1CN1',
#  'O=CC[C@H]1CO1',
#  'O=CCN1CC1',
#  'O=CNC1CC1',
#  'O=COC1CC1',
#  'CC#CC1CC1',
#  'CC#C[C@H]1CN1',
#  'CC#C[C@H]1CO1',
#  'CCCC1CC1',
#  'CCC[C@H]1CO1',
#  'CCCN1CC1',
#  'CCOC1CC1',
#  'COCC1CC1',
#  'COC[C@H]1CN1',
#  'COC[C@H]1CO1',
#  'OCCC1CC1',
#  'OCC[C@H]1CO1',
#  'OCCN1CC1',
#  'C[C@H]1C[C@H]1C#C',
#  'C[C@H]1C[C@H]1C#N',
#  'C[C@H]1N[C@H]1C#C',
#  'C[C@H]1N[C@H]1C#N',
#  'C[C@H]1O[C@H]1C#C',
#  'C[C@H]1O[C@H]1C#N',
#  'CN1C[C@H]1C#C',
#  'CN1C[C@H]1C#N',
#  'O[C@H]1C[C@H]1C#C',
#  'O[C@H]1C[C@H]1C#N',
#  'C[C@H]1C[C@H]1C=O',
#  'C[C@H]1CN1C=O',
#  'C[C@H]1N[C@H]1C=O',
#  'C[C@H]1O[C@H]1C=O',
#  'CN1C[C@H]1C=O',
#  'O[C@H]1C[C@H]1C=O',
#  'C[C@H]1C[C@H]1CO',
#  'C[C@H]1N[C@H]1CO',
#  'C[C@H]1O[C@H]1CO',
#  'CC[C@H]1C[C@H]1C',
#  'CC[C@H]1C[C@H]1O',
#  'CC[C@H]1CN1C',
#  'CC[C@H]1O[C@H]1C',
#  'CCN1C[C@H]1C',
#  'CN1C[C@H]1CO',
#  'CO[C@H]1C[C@H]1C',
#  'CO[C@H]1C[C@H]1O',
#  'OC[C@H]1C[C@H]1O',
#  'CC(=O)C1CC1',
#  'CC(=O)[C@H]1CN1',
#  'CC(=O)[C@H]1CO1',
#  'CC(=O)N1CC1',
#  'NC(=O)C1CC1',
#  'NC(=O)[C@H]1CN1',
#  'NC(=O)[C@H]1CO1',
#  'NC(=O)N1CC1',
#  'CC(C)C1CC1',
#  'CC(C)[C@H]1CO1',
#  'CC(C)N1CC1',
#  'C[C@@H](O)C1CC1',
#  'C[C@@H](O)[C@H]1CN1',
#  'C[C@@H](O)[C@H]1CO1',
#  'C1CC21CCC2',
#  'C1CC21CCO2',
#  'C1CC21COC2',
#  'C1NC21COC2',
#  'C1OC21CCC2',
#  'C1OC21COC2',
#  'C1[C@H]2C[C@@H]1C=C2',
#  'C1[C@H]2O[C@@H]1C=C2',
#  'C1[C@H]2C[C@@H]1CC2',
#  'C1[C@H]2C[C@@H]1OC2',
#  'C1[C@H]2CC[C@@H]1O2',
#  'C[C@H]1[C@H]2C[C@@H]1C2',
#  'C[C@H]1[C@H]2C[C@@H]1O2',
#  'O[C@H]1[C@H]2C[C@@H]1C2',
#  'O[C@H]1[C@H]2C[C@@H]1O2',
#  'C1CC=CCO1',
#  'C1CCC=CC1',
#  'C1COC=NC1',
#  'C1CCCCC1',
#  'C1CCOCC1',
#  'C1COCCO1',
#  'C1COCOC1',
#  'C1C[C@H]2CC[C@@H]12',
#  'C1C[C@H]2OC[C@@H]12',
#  'C1O[C@H]2CO[C@@H]12',
#  'C[C@H]1[C@H]2CC[C@@H]12',
#  'C[C@H]1[C@H]2CO[C@@H]12',
#  'O[C@H]1[C@H]2CC[C@@H]12',
#  'O[C@H]1[C@H]2CO[C@@H]12',
#  'C1[C@H]2CC=C[C@@H]12',
#  'C1[C@H]2OC=N[C@@H]12',
#  'C1C=C[C@H]2N[C@@H]12',
#  'C1C=C[C@H]2O[C@@H]12',
#  'C1[C@H]2CCC[C@@H]12',
#  'C1[C@H]2CCO[C@@H]12',
#  'C1[C@H]2COC[C@@H]12',
#  'C1[C@H]2OCO[C@@H]12',
#  'C1C[C@H]2O[C@H]2C1',
#  'C1OC[C@H]2N[C@@H]12',
#  'C1OC[C@H]2O[C@@H]12',
#  'N=C1O[C@H]2C[C@@H]12',
#  'O=C1C[C@H]2C[C@@H]12',
#  'O=C1C[C@H]2CN12',
#  'O=C1C[C@H]2N[C@@H]12',
#  'O=C1C[C@H]2O[C@@H]12',
#  'O=C1CN2C[C@@H]12',
#  'O=C1N[C@H]2C[C@@H]12',
#  'O=C1O[C@H]2C[C@@H]12',
#  'C[C@H]1C[C@H]2C[C@@H]12',
#  'C[C@H]1C[C@H]2O[C@@H]12',
#  'C[C@H]1O[C@H]2C[C@@H]12',
#  'O[C@H]1C[C@H]2C[C@@H]12',
#  'O[C@H]1C[C@H]2N[C@@H]12',
#  'O[C@H]1C[C@H]2O[C@@H]12',
#  'O[C@H]1CN2C[C@@H]12',
#  'C1[C@H]2[C@@H]3C[C@H]2[C@H]13',
#  'C1[C@H]2[C@@H]3CN2[C@H]13',
#  'C1[C@H]2[C@@H]3O[C@H]2[C@H]13',
#  'N1[C@H]2[C@@H]3N[C@H]2[C@H]13',
#  'N1[C@H]2[C@@H]3O[C@H]2[C@H]13',
#  'O1[C@H]2[C@@H]3O[C@H]2[C@H]13',
#  'C1CC1C1CC1',
#  'C1CC1[C@H]1CO1',
#  'C1CC1N1CC1',
#  'C1N[C@H]1[C@H]1CN1',
#  'C1N[C@H]1[C@H]1CO1',
#  'C1O[C@H]1[C@H]1CO1',
#  'C1[C@H]2[C@@H]1[C@H]1C[C@@H]21',
#  'C1[C@H]2[C@@H]1[C@H]1N[C@@H]21',
#  'C1[C@H]2[C@@H]1[C@H]1O[C@@H]21',
#  'C1[C@H]2[C@@H]1N1C[C@@H]21',
#  'N1[C@H]2[C@@H]1[C@H]1N[C@@H]21',
#  'N1[C@H]2[C@@H]1[C@H]1O[C@@H]21',
#  'O1[C@H]2[C@@H]1[C@H]1O[C@@H]21',
#  'C1[C@H]2[C@H]3[C@@H]1CN23',
#  'C1[C@H]2[C@H]3C[C@@H]1[C@@H]23',
#  'C1[C@H]2[C@H]3C[C@@H]1N23',
#  'C1[C@H]2[C@H]3CN1[C@@H]23',
#  'C1[C@H]2[C@H]3O[C@@H]1[C@@H]23',
#  '[C@H]12[C@@H]3[C@H]1[C@@H]1[C@H]2[C@H]31',
#  '[C@H]12[C@@H]3[C@H]1N1[C@H]2[C@H]31',
#  'c1cnncc1',
#  'c1cnnnc1',
#  'c1nncnn1',
#  'c1n[n]nc[n]1',
#  'c1nnnnc1',
#  'Cc1ccn[nH]1',
#  'Cc1ccno1',
#  'Cc1cnn[nH]1',
#  'Cc1cnno1',
#  'Cc1c[nH]nc1',
#  'Cc1c[nH]nn1',
#  'Cc1conc1',
#  'Cc1conn1',
#  'C[C]1N=C[N]N1',
#  'CC1=[N]=C[N]O1',
#  'Cc1n[nH]cc1',
#  'Cc1n[nH]cn1',
#  'Cc1n[nH]nc1',
#  'Cc1n[nH]nn1',
#  'Cc1nocc1',
#  'Cc1nocn1',
#  'Cc1nonc1',
#  'Cc1nonn1',
#  'Cn1cccn1',
#  'Cn1ccnn1',
#  'CN1[CH]N=C[N]1',
#  'Cn1cnnc1',
#  'Cn1cnnn1',
#  'Cn1nccn1',
#  'Cn1ncnn1',
#  'Cn1nnnn1',
#  'Nc1ccn[nH]1',
#  'Nc1ccno1',
#  'Nc1cnn[nH]1',
#  'Nc1cnno1',
#  'Nc1c[nH]nc1',
#  'Nc1c[nH]nn1',
#  'Nc1conc1',
#  'Nc1conn1',
#  'N[C]1N=C[N]N1',
#  'NC1=[N]=C[N]O1',
#  'Nc1n[nH]cc1',
#  'Nc1n[nH]cn1',
#  'Nc1n[nH]nc1',
#  'Nc1n[nH]nn1',
#  'Nc1nocc1',
#  'Nc1nocn1',
#  'Nc1nonc1',
#  'Nc1nonn1',
#  'O=c1[nH]cn[nH]1',
#  'O=c1[nH]cno1',
#  'O=c1[nH]nn[nH]1',
#  'O=c1[nH]nno1',
#  'O=c1ocno1',
#  'Oc1ccn[nH]1',
#  'Oc1c[nH]nc1',
#  'OC1=N[N]N[CH]1',
#  'OC1=[N]=C[N]N1',
#  'Oc1n[nH]cc1',
#  'O[C]1=NN[CH]N=1',
#  'Oc1n[nH]nc1',
#  'Oc1n[nH]nn1',
#  'Oc1nocc1',
#  'Oc1nocn1',
#  'Oc1nonn1',
#  'CC#C/C(=N/O)/C',
#  'C/C(=N\\O)/CC#C',
#  'C/C(=N\\O)/CC#N',
#  'C/C(=N\\O)/CC=O',
#  'C/C(=N\\O)/CCO',
#  'CCC/C(=N/O)/C',
#  'COC/C(=N/O)/C',
#  'C/C(=N\\O)/C(=N/O)/C',
#  'C/C(=N\\O)/C(=O)N',
#  'CC(C)/C(=N/O)/C',
#  'C[C@@H](O)/C(=N/O)/C',
#  'C[C@H]1C/C(=N/O)/C1',
#  'CN1CC(=NO)C1',
#  'O/N=C/1\\C[C@@H](O)C1',
#  'ON=C(C#C)C#C',
#  'CC/C(=N\\O)/C#C',
#  'OC/C(=N\\O)/C#C',
#  'CCC(=NO)CC',
#  'CC/C(=N\\O)/CO',
#  'C[C@H]1CC/C/1=N\\O',
#  'C[C@H]1NC/C/1=N\\O',
#  'C[C@H]1OC/C/1=N\\O',
#  'O/N=C/1\\CC[C@H]1O',
#  'O/N=C/1\\CC=CC1',
#  'O/N=C\\1/CCC=C1',
#  'O/N=C\\1/CNC=C1',
#  'ON=C1CCCC1',
#  'O/N=C\\1/CCOC1',
#  'C/C(=N\\O)/C1CC1',
#  'C/C(=N\\O)/[C@H]1CN1',
#  'C/C(=N\\O)/[C@H]1CO1',
#  'O/N=C/1\\C[C@H]2C[C@@H]12',
#  'O/N=C/1\\C[C@H]2N[C@@H]12',
#  'O/N=C/1\\C[C@H]2O[C@@H]12',
#  'O/N=C/1\\CN2C[C@@H]12',
#  'FC(F)(F)C#C',
#  'FC(F)(F)C=O',
#  'NCC(F)(F)F',
#  'OCC(F)(F)F',
#  'CCC(F)(F)F',
#  'Cc1cc(C)c[nH]1',
#  'Cc1cc(C)co1',
#  'Cc1cc(N)c[nH]1',
#  'Cc1cc(N)co1',
#  'Cc1cc(O)c[nH]1',
#  'Cc1cc(O)co1',
#  'Cc1c[nH]c(N)c1',
#  'Cc1c[nH]c(O)c1',
#  'Cc1c[nH]c(O)n1',
#  'Cc1coc(N)c1',
#  'Cc1coc(N)n1',
#  'Cc1coc(O)n1',
#  'Cc1nc(C)c[nH]1',
#  'Cc1nc(C)co1',
#  'Cc1nc(N)co1',
#  'C[C]1N=C(O)[CH]N1',
#  'CC1=[N]=C(O)[CH]O1',
#  'Nc1cc(N)c[nH]1',
#  'Nc1cc(N)co1',
#  'Nc1cc(O)c[nH]1',
#  'Nc1cc(O)co1',
#  'Nc1c[nH]c(O)c1',
#  'Nc1c[nH]c(O)n1',
#  'Nc1coc(O)n1',
#  'Nc1nc(N)co1',
#  'N[C]1N=C(O)[CH]N1',
#  'NC1=[N]=C(O)[CH]O1',
#  'Oc1cc(O)c[nH]1',
#  'OC1=[N]=C(O)[CH]N1',
#  'Cc1ccc(C)[nH]1',
#  'Cc1ccc(C)o1',
#  'Cc1ccc(N)[nH]1',
#  'Cc1ccc(N)o1',
#  'Cc1ccc(O)[nH]1',
#  'Cc1cnc(C)o1',
#  'Cc1cnc(N)o1',
#  'Cc1cnc(O)[nH]1',
#  'Cc1cnc(O)o1',
#  'Cc1ncc(N)o1',
#  'Cc1ncc(O)[nH]1',
#  'Nc1ccc(N)[nH]1',
#  'Nc1ccc(N)o1',
#  'Nc1ccc(O)[nH]1',
#  'Nc1ccc(O)o1',
#  'Nc1cnc(N)o1',
#  'Nc1cnc(O)[nH]1',
#  'Nc1cnc(O)o1',
#  'Oc1ccc(O)[nH]1',
#  'Oc1cnc(O)[nH]1',
#  'Cc1c[nH]c(=O)[nH]1',
#  'Cc1c[nH]c(=O)o1',
#  'Cc1coc(=O)[nH]1',
#  'Cc1coc(=O)o1',
#  'Nc1c[nH]c(=O)[nH]1',
#  'Nc1c[nH]c(=O)o1',
#  'Nc1coc(=O)[nH]1',
#  'Nc1coc(=O)o1',
#  'Oc1c[nH]c(=O)[nH]1',
#  'Oc1c[nH]c(=O)o1',
#  'Oc1coc(=O)o1',
#  'Cn1ccc(C)c1',
#  'Cn1ccc(N)c1',
#  'Cn1ccc(O)c1',
#  'Cn1cnc(C)c1',
#  'Cn1cnc(N)c1',
#  'CN1[CH]N=C(O)[CH]1',
#  'O=c1cc[nH]cc1',
#  'O=c1cc[nH]cn1',
#  'O=c1ccocc1',
#  'O=c1ccocn1',
#  'O=[C]1=[N]=COC=N1',
#  'N=c1occcc1',
#  '[NH]C1=NC=C[CH]O1',
#  '[NH]C1=C[N]C=CO1',
#  'N=c1ocncc1',
#  '[NH]C1=NC=[N]=CO1',
#  'O=c1[nH]cccc1',
#  'O=c1[nH]cccn1',
#  'O=c1[nH]ccnc1',
#  'O=c1[nH]cncc1',
#  'O=C1N[CH]N=C[N]1',
#  'O=c1occcc1',
#  'O=[C]1=NC=C[CH]O1',
#  'O=c1occnc1',
#  'O=c1ocncc1',
#  'O=[C]1=NC=[N]=CO1',
#  'Cc1ccccc1',
#  'Cc1ccncc1',
#  'Cc1cnccc1',
#  'Cc1cnccn1',
#  'Cc1cncnc1',
#  'Cc1ncccc1',
#  'Cc1ncccn1',
#  'Cc1nccnc1',
#  'Cc1ncncc1',
#  'CC1=[N]=CN=C[N]1',
#  'Nc1ccccc1',
#  'Nc1cnccc1',
#  'Nc1cnccn1',
#  'Nc1cncnc1',
#  'Nc1ncccc1',
#  'Nc1ncccn1',
#  'Nc1nccnc1',
#  'Nc1ncncc1',
#  'NC1=[N]=CN=C[N]1',
#  'Oc1ccccc1',
#  'Oc1ccncc1',
#  'Oc1cnccc1',
#  'Oc1cnccn1',
#  'Oc1cncnc1',
#  'Oc1ncccc1',
#  'O[C]1=N[CH]C=CN=1',
#  'Oc1nccnc1',
#  'OC1=[N]=CN=C[CH]1',
#  'O[C]1=[N]=CN=CN=1',
#  'Cc1c(C)cc[nH]1',
#  'Cc1c(C)cco1',
#  'Cc1c(C)nc[nH]1',
#  'Cc1c(C)nco1',
#  'Cc1c(N)cc[nH]1',
#  'Cc1c(N)cco1',
#  'Cc1c(N)nco1',
#  'Cc1c(N)[nH]cc1',
#  'Cc1c(N)occ1',
#  'Cc1c(N)ocn1',
#  'Cc1c(O)cc[nH]1',
#  'Cc1c(O)cco1',
#  'C[C]1C(=N[CH]N1)O',
#  'C[C]1C(=[N]=CO1)O',
#  'Cc1c(O)[nH]cc1',
#  'Cc1c(O)[nH]cn1',
#  'Nc1c(N)cco1',
#  'Nc1c(N)nco1',
#  'Nc1c(O)cc[nH]1',
#  'Nc1c(O)cco1',
#  'N[C]1C(=N[CH]N1)O',
#  'N[C]1C(=[N]=CO1)O',
#  'Nc1c(O)[nH]cc1',
#  'Nc1c(O)[nH]cn1',
#  'Nc1c(O)occ1',
#  'Oc1c(O)cc[nH]1',
#  'O[C]1C(=N[CH]N1)O',
#  'Cc1c[nH]cc1C',
#  'Cc1c[nH]cc1N',
#  'Cc1c[nH]cc1O',
#  'Cc1cocc1C',
#  'Cc1cocc1N',
#  'Nc1c[nH]cc1N',
#  'Nc1c[nH]cc1O',
#  'Nc1cocc1N',
#  'Oc1c[nH]cc1O',
#  'Cn1cccc1C',
#  'Cn1cccc1N',
#  'Cn1cccc1O',
#  'Cn1ccnc1C',
#  'Cn1ccnc1O',
#  'Cn1cncc1C',
#  'Cn1cncc1O',
#  'Cn1cc[nH]c1=O',
#  'Cn1ccoc1=O',
#  'C#Cc1ccc[nH]1',
#  'C#Cc1ccco1',
#  'C#Cc1cnc[nH]1',
#  'C#Cc1cnco1',
#  'C#Cc1ncc[nH]1',
#  'C#Cc1ncco1',
#  'N#Cc1ccc[nH]1',
#  'N#Cc1ccco1',
#  'N#Cc1cnc[nH]1',
#  'N#Cc1cnco1',
#  'N#Cc1ncc[nH]1',
#  'N#Cc1ncco1',
#  'C#Cc1c[nH]cc1',
#  'C#Cc1c[nH]cn1',
#  'C#Cc1cocc1',
#  'C#Cc1cocn1',
#  'N#Cc1c[nH]cc1',
#  'N#Cc1c[nH]cn1',
#  'N#Cc1cocc1',
#  'N#Cc1cocn1',
#  'O=Cc1ccc[nH]1',
#  'O=Cc1ccco1',
#  'O=Cc1cnc[nH]1',
#  'O=Cc1cnco1',
#  'O=Cc1ncc[nH]1',
#  'O=Cc1ncco1',
#  'O=Cc1c[nH]cc1',
#  'O=Cc1c[nH]cn1',
#  'O=Cc1cocc1',
#  'O=Cc1cocn1',
#  ...]

# %%
smiles = np.concatenate(features_chunk)

# %%
smiles[110]
# Out:
# 'CC#CC#N'

# %%
df_smiles = pd.DataFrame({'molecule_name': mol_name, 'smiles': smiles})
# Out:
#           molecule_name smiles
# 0  dsgdb9nsd_000001.xyz      C
# 1  dsgdb9nsd_000002.xyz      N
# 2  dsgdb9nsd_000003.xyz      O
# 3  dsgdb9nsd_000004.xyz    C#C
# 4  dsgdb9nsd_000005.xyz    C#N

# %%
df_smiles.sort_values("molecule_name", inplace=True)

# %%
df_smiles.head()
# Out:
#           molecule_name smiles
# 0  dsgdb9nsd_000001.xyz      C
# 1  dsgdb9nsd_000002.xyz      N
# 2  dsgdb9nsd_000003.xyz      O
# 3  dsgdb9nsd_000004.xyz    C#C
# 4  dsgdb9nsd_000005.xyz    C#N

# %%
smiles = df_smiles["smiles"].values

# %%
model = Word2Vec.load('../input/model_300dim.pkl')

# %%
def func(smiles):
    ret_list = []
    for s in tqdm(smiles): #data["smiles"]:
        try:
            sentence = mol2alt_sentence(Chem.MolFromSmiles(s), 1)
        except Exception as e:
            ret_list += [[np.nan]*300]
            continue
            
        for cnt in range(len(sentence)):
            try:
                ret_list += [model.wv[sentence[cnt]]]
                break
            except Exception as e:
                #print(s)
                #print(sentence)
                pass
            
            ret_list += [[np.nan]*300]
    return ret_list

# %%
mol_vec = func(smiles)
# Out:
# HBox(children=(IntProgress(value=0, max=130775), HTML(value='')))

# %%
mol_vec = np.array(mol_vec)

# %%
mol_vec.shape
# Out:
# (130775, 300)

# %%
mol_vec_df = pd.DataFrame(mol_vec)

# %%
mol_vec_df.isna().sum()
# Out:
# 0      2054
# 1      2054
# 2      2054
# 3      2054
# 4      2054
#        ...
# 295    2054
# 296    2054
# 297    2054
# 298    2054
# 299    2054
# Length: 300, dtype: int64

# %%
structures = pd.read_csv("../input/structures.csv")
train = pd.read_csv("../input/train.csv")
mol_vec_df["molecule_name"] = np.sort(structures.molecule_name.unique())

# %%
mol_vec_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1 -0.306596  0.223230 -0.165032  0.340601  0.122465  0.127082 -0.055324
# 2 -0.181573 -0.156637 -0.001124 -0.450791  0.018562  0.175651 -0.293198
# 3  0.211415  0.029348  0.351280  0.371282  0.780693 -0.099970 -0.497356
# 4  0.211415  0.029348  0.351280  0.371282  0.780693 -0.099970 -0.497356
#
#           7         8         9  ...       291       292       293       294  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1 -0.256667  0.035283  0.287777  ...  0.392870  0.049481  0.146393  0.178297
# 2 -0.016114  0.120915  0.384910  ...  0.369871  0.038316  0.128176  0.131276
# 3  0.217432  0.498350 -0.008529  ...  0.021449  0.370440  0.156537 -0.936061
# 4  0.217432  0.498350 -0.008529  ...  0.021449  0.370440  0.156537 -0.936061
#
#         295       296       297       298       299     molecule_name
# 0       NaN       NaN       NaN       NaN       NaN  dsgdb9nsd_000001
# 1 -0.338194  0.009021  0.305351 -0.513758  0.322367  dsgdb9nsd_000002
# 2  0.024598 -0.127479 -0.072179 -0.445017  0.018748  dsgdb9nsd_000003
# 3  0.257772 -0.111415 -0.470363 -0.260219  0.209732  dsgdb9nsd_000004
# 4  0.257772 -0.111415 -0.470363 -0.260219  0.209732  dsgdb9nsd_000005
#
# [5 rows x 301 columns]

# %%
train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
train = train.merge(mol_vec_df, on="molecule_name", how="left")

# %%
mol_vec_df.columns = [f"vec_{c}" for c in range(300)] + ["molecule_name"]

# %%
mol_vec_df.head()
# Out:
#       vec_0     vec_1     vec_2     vec_3     vec_4     vec_5     vec_6  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1 -0.306596  0.223230 -0.165032  0.340601  0.122465  0.127082 -0.055324
# 2 -0.181573 -0.156637 -0.001124 -0.450791  0.018562  0.175651 -0.293198
# 3  0.211415  0.029348  0.351280  0.371282  0.780693 -0.099970 -0.497356
# 4  0.211415  0.029348  0.351280  0.371282  0.780693 -0.099970 -0.497356
#
#       vec_7     vec_8     vec_9  ...   vec_291   vec_292   vec_293   vec_294  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1 -0.256667  0.035283  0.287777  ...  0.392870  0.049481  0.146393  0.178297
# 2 -0.016114  0.120915  0.384910  ...  0.369871  0.038316  0.128176  0.131276
# 3  0.217432  0.498350 -0.008529  ...  0.021449  0.370440  0.156537 -0.936061
# 4  0.217432  0.498350 -0.008529  ...  0.021449  0.370440  0.156537 -0.936061
#
#     vec_295   vec_296   vec_297   vec_298   vec_299     molecule_name
# 0       NaN       NaN       NaN       NaN       NaN  dsgdb9nsd_000001
# 1 -0.338194  0.009021  0.305351 -0.513758  0.322367  dsgdb9nsd_000002
# 2  0.024598 -0.127479 -0.072179 -0.445017  0.018748  dsgdb9nsd_000003
# 3  0.257772 -0.111415 -0.470363 -0.260219  0.209732  dsgdb9nsd_000004
# 4  0.257772 -0.111415 -0.470363 -0.260219  0.209732  dsgdb9nsd_000005
#
# [5 rows x 301 columns]

# %%
to_pickle("../processed/v003/mol_vec_df.pkl", mol_vec_df)
