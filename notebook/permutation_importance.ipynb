# %%
import os
import sys
import os
import datetime
import json
import gc
import time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from numba import jit

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold
import warnings
warnings.filterwarnings("ignore")

sys.path.append('..')
from lib.line_notif import send_message
from lib.utils import current_time, unpickle, to_pickle, reduce_mem_usage

import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split

def group_mean_log_mae(y_true, y_pred, types, floor=1e-9):
    """
    Fast metric computation for this competition: https://www.kaggle.com/c/champs-scalar-coupling
    Code is from this kernel: https://www.kaggle.com/uberkinder/efficient-metric
    """
    maes = (y_true - y_pred).abs().groupby(types).mean()
    return np.log(maes.map(lambda x: max(x, floor))).mean()

# %%
use_cols = """molecule_atom_index_0_dist_min
molecule_atom_index_0_dist_max
molecule_atom_index_1_dist_min
molecule_atom_index_0_dist_mean
molecule_atom_index_0_dist_std
dist
abs_dist
x_0
y_0
z_0
x_1
y_1
z_1
molecule_atom_index_1_dist_std
molecule_atom_index_1_dist_max
molecule_atom_index_1_dist_mean
molecule_atom_index_0_dist_max_diff
molecule_atom_index_0_dist_max_div
molecule_atom_index_0_dist_std_diff
molecule_atom_index_0_dist_std_div
atom_0_couples_count
molecule_atom_index_0_dist_min_div
molecule_atom_index_1_dist_std_diff
molecule_atom_index_0_dist_mean_div
atom_1_couples_count
molecule_atom_index_0_dist_mean_diff
molecule_couples
atom_index_1
molecule_dist_mean
molecule_atom_index_1_dist_max_diff
molecule_atom_index_0_y_1_std
molecule_atom_index_1_dist_mean_diff
molecule_atom_index_1_dist_std_div
molecule_atom_index_1_dist_mean_div
molecule_atom_index_1_dist_min_diff
molecule_atom_index_1_dist_min_div
molecule_atom_index_1_dist_max_div
molecule_atom_index_0_z_1_std
molecule_type_dist_std_diff
molecule_atom_1_dist_min_diff
molecule_atom_index_0_x_1_std
molecule_dist_min
molecule_atom_index_0_dist_min_diff
molecule_atom_index_0_y_1_mean_diff
molecule_type_dist_min
molecule_atom_1_dist_min_div
atom_index_0
molecule_dist_max
molecule_atom_1_dist_std_diff
molecule_type_dist_max
molecule_atom_index_0_y_1_max_diff
molecule_type_0_dist_std_diff
molecule_type_dist_mean_diff
molecule_atom_1_dist_mean
molecule_atom_index_0_y_1_mean_div
molecule_type_dist_mean_div
type
f004:angle
f004:angle_abs
f006:dist_origin_mean
f006:dist_from_origin_0
f006:dist_from_origin_1
Angle
Torsion
cos2T
cosT
dist_xy
dist_xz
dist_yz
C
H
N
O
eem_0
mmff94_0
gasteiger_0
qeq_0
qtpie_0
eem2015ha_0
eem2015hm_0
eem2015hn_0
eem2015ba_0
eem2015bm_0
eem2015bn_0
eem_1
mmff94_1
gasteiger_1
qeq_1
qtpie_1
eem2015ha_1
eem2015hm_1
eem2015hn_1
eem2015ba_1
eem2015bm_1
eem2015bn_1
dist_H_0_x
dist_H_1_x
dist_H_2_x
dist_H_3_x
dist_H_4_x
dist_C_0_x
dist_C_1_x
dist_C_2_x
dist_C_3_x
dist_C_4_x
dist_N_0_x
dist_N_1_x
dist_N_2_x
dist_N_3_x
dist_N_4_x
dist_O_0_x
dist_O_1_x
dist_O_2_x
dist_O_3_x
dist_F_0_x
dist_F_1_x
dist_H_0_y
dist_H_1_y
dist_H_2_y
dist_H_3_y
dist_H_4_y
dist_C_0_y
dist_C_1_y
dist_C_2_y
dist_C_3_y
dist_C_4_y
dist_N_0_y
dist_N_1_y
dist_N_2_y
dist_N_3_y
dist_N_4_y
dist_O_0_y
dist_O_1_y
dist_O_2_y
dist_O_3_y
dist_F_0_y
dist_F_1_y
tda_max_radius
tda_min_radius
a1_degree
a1_hybridization
a1_inring
a1_inring3
a1_inring4
a1_inring5
a1_inring6
a1_inring7
a1_inring8
a1_nb_h
a1_nb_o
a1_nb_c
a1_nb_n
a1_nb_na
a0_nb_degree
a0_nb_hybridization
a0_nb_inring
a0_nb_inring3
a0_nb_inring4
a0_nb_inring5
a0_nb_inring6
a0_nb_inring7
a0_nb_inring8
a0_nb_nb_h
a0_nb_nb_o
a0_nb_nb_c
a0_nb_nb_n
a0_nb_nb_na
x_a0_nb
y_a0_nb
z_a0_nb
a1_nb_degree
a1_nb_hybridization
a1_nb_inring
a1_nb_inring3
a1_nb_inring4
a1_nb_inring5
a1_nb_inring6
a1_nb_inring7
a1_nb_inring8
a1_nb_nb_h
a1_nb_nb_o
a1_nb_nb_c
a1_nb_nb_n
a1_nb_nb_na
x_a1_nb
y_a1_nb
z_a1_nb
dist_to_type_mean""".split("\n")

# %%
DATA_VERSION = "v003"
TRIAL_NO = "029"

sys.path.append("../src")
import importlib
use_cols = importlib.import_module(f'use_cols_{DATA_VERSION}_{TRIAL_NO}')
# use_cols = importlib.import_module(f'use_cols')
print(use_cols.good_columns)

save_path = Path(f"../processed/{DATA_VERSION}")
save_path.mkdir(parents=True, exist_ok=True)
model_path = Path(f"../model/{DATA_VERSION}_{TRIAL_NO}")
model_path.mkdir(parents=True, exist_ok=True)
submit_path = Path(f"../submit/{DATA_VERSION}_{TRIAL_NO}")
submit_path.mkdir(parents=True, exist_ok=True)
log_path = Path(f"../log/{DATA_VERSION}_{TRIAL_NO}")
log_path.mkdir(parents=True, exist_ok=True)
# Out:
# ['molecule_atom_index_0_dist_min', 'molecule_atom_index_0_dist_max', 'molecule_atom_index_1_dist_min', 'molecule_atom_index_0_dist_mean', 'molecule_atom_index_0_dist_std', 'dist', 'abs_dist', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'molecule_atom_index_1_dist_std', 'molecule_atom_index_1_dist_max', 'molecule_atom_index_1_dist_mean', 'molecule_atom_index_0_dist_max_diff', 'molecule_atom_index_0_dist_max_div', 'molecule_atom_index_0_dist_std_diff', 'molecule_atom_index_0_dist_std_div', 'atom_0_couples_count', 'molecule_atom_index_0_dist_min_div', 'molecule_atom_index_1_dist_std_diff', 'molecule_atom_index_0_dist_mean_div', 'atom_1_couples_count', 'molecule_atom_index_0_dist_mean_diff', 'molecule_couples', 'atom_index_1', 'molecule_dist_mean', 'molecule_atom_index_1_dist_max_diff', 'molecule_atom_index_0_y_1_std', 'molecule_atom_index_1_dist_mean_diff', 'molecule_atom_index_1_dist_std_div', 'molecule_atom_index_1_dist_mean_div', 'molecule_atom_index_1_dist_min_diff', 'molecule_atom_index_1_dist_min_div', 'molecule_atom_index_1_dist_max_div', 'molecule_atom_index_0_z_1_std', 'molecule_type_dist_std_diff', 'molecule_atom_1_dist_min_diff', 'molecule_atom_index_0_x_1_std', 'molecule_dist_min', 'molecule_atom_index_0_dist_min_diff', 'molecule_atom_index_0_y_1_mean_diff', 'molecule_type_dist_min', 'molecule_atom_1_dist_min_div', 'atom_index_0', 'molecule_dist_max', 'molecule_atom_1_dist_std_diff', 'molecule_type_dist_max', 'molecule_atom_index_0_y_1_max_diff', 'molecule_type_0_dist_std_diff', 'molecule_type_dist_mean_diff', 'molecule_atom_1_dist_mean', 'molecule_atom_index_0_y_1_mean_div', 'molecule_type_dist_mean_div', 'type', 'f004:angle', 'f004:angle_abs', 'f006:dist_origin_mean', 'f006:dist_from_origin_0', 'f006:dist_from_origin_1', 'Angle', 'Torsion', 'cos2T', 'cosT', 'dist_xy', 'dist_xz', 'dist_yz', 'C', 'H', 'N', 'O', 'eem_0', 'mmff94_0', 'gasteiger_0', 'qeq_0', 'qtpie_0', 'eem2015ha_0', 'eem2015hm_0', 'eem2015hn_0', 'eem2015ba_0', 'eem2015bm_0', 'eem2015bn_0', 'eem_1', 'mmff94_1', 'gasteiger_1', 'qeq_1', 'qtpie_1', 'eem2015ha_1', 'eem2015hm_1', 'eem2015hn_1', 'eem2015ba_1', 'eem2015bm_1', 'eem2015bn_1', 'dist_H_0_x', 'dist_H_1_x', 'dist_H_2_x', 'dist_H_3_x', 'dist_H_4_x', 'dist_C_0_x', 'dist_C_1_x', 'dist_C_2_x', 'dist_C_3_x', 'dist_C_4_x', 'dist_N_0_x', 'dist_N_1_x', 'dist_N_2_x', 'dist_N_3_x', 'dist_N_4_x', 'dist_O_0_x', 'dist_O_1_x', 'dist_O_2_x', 'dist_O_3_x', 'dist_F_0_x', 'dist_F_1_x', 'dist_H_0_y', 'dist_H_1_y', 'dist_H_2_y', 'dist_H_3_y', 'dist_H_4_y', 'dist_C_0_y', 'dist_C_1_y', 'dist_C_2_y', 'dist_C_3_y', 'dist_C_4_y', 'dist_N_0_y', 'dist_N_1_y', 'dist_N_2_y', 'dist_N_3_y', 'dist_N_4_y', 'dist_O_0_y', 'dist_O_1_y', 'dist_O_2_y', 'dist_O_3_y', 'dist_F_0_y', 'dist_F_1_y', 'tda_max_radius', 'tda_min_radius']

# %%
train = unpickle(save_path/f"v003_029/train_concat_v003_029.pkl", )
test = unpickle(save_path/f"v003_029/test_concat_v003_029.pkl", )

X = train[use_cols].copy()
y = train['scalar_coupling_constant']
X_test = test[use_cols].copy()

# %%
len(use_cols)
# Out:
# 188

# %%
train.shape, X.shape
# Out:
# ((4658147, 233), (4658147, 188))

# %%
seed = 71
model = unpickle(model_path / f"hold_out_model_{DATA_VERSION}_{TRIAL_NO}_{seed}.pkl", )

# %%
columns=None
columns = X.columns if columns is None else columns
X_train, X_valid, y_train, y_valid = train_test_split(X[columns], y, test_size=0.1, random_state=42)

# %%
model
# Out:
# LGBMRegressor(bagging_seed=72, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=1.0, feature_fraction_seed=73,
#        importance_type='split', learning_rate=0.2, max_depth=9,
#        metric='mae', min_child_samples=79, min_child_weight=0.001,
#        min_split_gain=0.0, n_estimators=8000, n_jobs=-1, num_leaves=128,
#        num_threads=-1, objective='regression', random_state=None,
#        reg_alpha=0.1, reg_lambda=0.3, seed=71, silent=True, subsample=0.9,
#        subsample_for_bin=200000, subsample_freq=1, verbosity=-1)

# %%
X_train.head()
# Out:
#          molecule_atom_index_0_dist_min  molecule_atom_index_0_dist_max  \
# 3930804                        1.095932                        3.617360
# 258790                         1.105069                        3.072265
# 1533600                        1.095765                        3.314278
# 3222881                        1.094762                        2.870522
# 3064518                        1.087312                        3.573952
#
#          molecule_atom_index_1_dist_min  molecule_atom_index_0_dist_mean  \
# 3930804                        1.093289                         2.472062
# 258790                         1.765062                         2.437990
# 1533600                        1.083687                         2.421280
# 3222881                        1.104260                         2.152555
# 3064518                        2.133517                         2.489014
#
#          molecule_atom_index_0_dist_std      dist  abs_dist       x_0  \
# 3930804                        0.947710  1.095932  1.718096 -1.485696
# 258790                         0.563292  2.503735  3.664633  0.576237
# 1533600                        0.767309  3.157974  4.865069  1.722459
# 3222881                        0.761025  2.171913  3.065948 -0.353353
# 3064518                        0.836157  2.133517  2.843518  3.883479
#
#               y_0       z_0        ...          a1_nb_inring8  a1_nb_nb_h  \
# 3930804  1.792534  0.339412        ...                      0           0
# 258790   0.100403 -2.064712        ...                      0           3
# 1533600  4.999507  1.215382        ...                      0           0
# 3222881  2.066271  0.767856        ...                      0           0
# 3064518  0.313637  1.556840        ...                      0           1
#
#          a1_nb_nb_o  a1_nb_nb_c  a1_nb_nb_n  a1_nb_nb_na   x_a1_nb   y_a1_nb  \
# 3930804           0           1           0            0 -1.485696  1.792534
# 258790            0           1           0            0  2.135812 -0.695696
# 1533600           0           1           0            0  1.339926  2.703822
# 3222881           0           1           0            0 -1.104999 -0.190652
# 3064518           0           1           0            0  4.963581  1.165528
#
#           z_a1_nb  dist_to_type_mean
# 3930804  0.339412           1.002775
# 258790  -0.800948           0.926581
# 1533600 -2.219744           1.025633
# 3222881  0.091709           0.991561
# 3064518 -1.389071           0.974032
#
# [5 rows x 188 columns]

# %%
from tqdm import tqdm_notebook as tqdm

# %%
y_pred_valid = model.predict(X_valid)
score = group_mean_log_mae(y_valid, y_pred_valid, X_valid['type'])
print(f"score: {score}")
# Out:
# score: -1.1120130623643119

# %%
np.random.seed(71)
result_list = []
for c in tqdm(X_valid.columns):
    if c  == "type": continue
    X_valid_ = X_valid.copy()
    np.random.shuffle(X_valid_[c].values)
    y_pred_valid = model.predict(X_valid_)
    score = group_mean_log_mae(y_valid, y_pred_valid, X_valid_['type'])
    print(f"col:{c}, score: {score}")
    result_list += [{"col":c, "score":score}]
# Out:
# HBox(children=(IntProgress(value=0, max=188), HTML(value='')))
# col:molecule_atom_index_0_dist_min, score: -0.8016989676908528
# col:molecule_atom_index_0_dist_max, score: -0.835570230386695
# col:molecule_atom_index_1_dist_min, score: -0.8568424887135307
# col:molecule_atom_index_0_dist_mean, score: -1.0151867421155965
# col:molecule_atom_index_0_dist_std, score: -1.0647992259171388
# col:dist, score: 0.5974748596606333
# col:abs_dist, score: -1.048671312384502
# col:x_0, score: -1.100368103716089
# col:y_0, score: -1.0827545244819905
# col:z_0, score: -1.1016572002387568
# col:x_1, score: -1.0942721757895792
# col:y_1, score: -1.0637109338257633
# col:molecule_atom_index_0_dist_max_diff, score: -0.7983006755317116
# col:molecule_atom_index_0_dist_max_div, score: -0.7245568108524868
# col:molecule_atom_index_0_dist_std_diff, score: -0.8999561148573347
# col:molecule_atom_index_0_dist_std_div, score: -0.7957186021297646
# col:atom_0_couples_count, score: -1.0617480907255836
# col:molecule_atom_index_0_dist_min_div, score: -0.620996527273829
# col:molecule_atom_index_1_dist_std_diff, score: -0.9831655306358067
# col:molecule_atom_index_0_dist_mean_div, score: -0.9949934202570292
# col:atom_1_couples_count, score: -1.0738364829165024
# col:molecule_atom_index_0_dist_mean_diff, score: -0.882153800394189
# col:molecule_couples, score: -1.086649260029389
# col:atom_index_1, score: -1.0752612359162876
# col:molecule_dist_mean, score: -1.0796881049639429
# col:molecule_atom_index_1_dist_max_diff, score: -0.9106591135024789
# col:molecule_atom_index_0_y_1_std, score: -1.0999717276846066
# col:molecule_atom_index_1_dist_mean_diff, score: -1.0295542339704955
# col:molecule_atom_index_1_dist_std_div, score: -1.0414821263422622
# col:molecule_atom_index_1_dist_mean_div, score: -1.0059168386850645
# col:molecule_atom_index_1_dist_min_diff, score: -0.9190961422567276
# col:molecule_atom_index_1_dist_min_div, score: -0.9597242391334646
# col:molecule_atom_index_1_dist_max_div, score: -0.9851616350920014
# col:molecule_atom_index_0_z_1_std, score: -1.1042681432069974
# col:molecule_type_dist_std_diff, score: -0.9430121401435674
# col:molecule_atom_1_dist_min_diff, score: -0.895641355963292
# col:molecule_atom_index_0_x_1_std, score: -1.1057094705306696
# col:molecule_dist_min, score: -1.0288006281653113
# col:molecule_atom_index_0_dist_min_diff, score: -0.5986666115460176
# col:molecule_atom_index_0_y_1_mean_diff, score: -1.0945744435053282
# col:molecule_type_dist_min, score: 1.1393919322684298
# col:molecule_atom_1_dist_min_div, score: -0.9862541466692796
# col:atom_index_0, score: -1.1066304331556325
# col:molecule_dist_max, score: -1.100053948558569
# col:molecule_atom_1_dist_std_diff, score: -0.9937510079823766
# col:molecule_type_dist_max, score: -0.9310570111681581
# col:molecule_atom_index_0_y_1_max_diff, score: -1.088662111945625
# col:molecule_type_0_dist_std_diff, score: -0.6735956966628129
# col:molecule_type_dist_mean_diff, score: -1.0353074406000962
# col:molecule_atom_1_dist_mean, score: -1.1001096683398157
# col:molecule_atom_index_0_y_1_mean_div, score: -1.100771247560751
# col:molecule_type_dist_mean_div, score: -1.042827548875327
# col:f004:angle, score: -1.1060880104653257
# col:f004:angle_abs, score: -1.1087329146359395
# col:f006:dist_origin_mean, score: -1.0938447773130076
# col:f006:dist_from_origin_0, score: -1.0425298764941875
# col:f006:dist_from_origin_1, score: -0.9864018727159477
# col:Angle, score: 0.07284437296497037
# col:Torsion, score: -1.08111199684059
# col:cos2T, score: 0.11477182106211034
# col:cosT, score: -0.40648857851572695
# col:dist_xy, score: -1.0809559548983534
# col:dist_xz, score: -1.0641049893603973
# col:dist_yz, score: -1.0921046194508808
# col:C, score: -1.1008993490147454
# col:H, score: -1.0817950667236158
# col:N, score: -1.111934922252888
# col:O, score: -1.1089548396594637
# col:eem_0, score: -0.8603337123684465
# col:mmff94_0, score: -0.42306638490812476
# col:gasteiger_0, score: -0.5181657339449803
# col:qeq_0, score: -1.0110208799856255
# col:qtpie_0, score: -0.9548512549858514
# col:eem2015ha_0, score: -1.086022276963714
# col:eem2015hm_0, score: -1.0559748782560363
# col:eem2015hn_0, score: -1.0647298738632385
# col:eem2015ba_0, score: -1.0790725382572695
# col:eem2015bm_0, score: -0.9997746759994246
# col:qeq_1, score: -0.9783644579456101
# col:qtpie_1, score: -0.9787412551498703
# col:eem2015ha_1, score: -0.9872107747725385
# col:eem2015hm_1, score: -0.9988045920870294
# col:eem2015hn_1, score: -1.049511050508798
# col:eem2015ba_1, score: -0.7356206261142704
# col:eem2015bm_1, score: -0.905534035733876
# col:dist_H_2_x, score: -0.9475880415639777
# col:dist_H_3_x, score: -1.0405332223099015
# col:dist_H_4_x, score: -1.0558800256645131
# col:dist_C_0_x, score: -0.5674973063923796
# col:dist_C_1_x, score: -0.6937435270387498
# col:dist_C_2_x, score: -0.6456130197266989
# col:dist_C_3_x, score: -0.8094709261516642
# col:dist_C_4_x, score: -1.0090465282848864
# col:dist_N_0_x, score: -0.639355345696898
# col:dist_N_1_x, score: -1.0259465914711574
# col:dist_N_2_x, score: -1.1024348267150221
# col:dist_N_3_x, score: -1.1111523921437083
# col:dist_N_4_x, score: -1.1118072658881508
# col:dist_O_0_x, score: -0.6143400541240555
# col:dist_O_1_x, score: -0.9965850173223768
# col:dist_O_2_x, score: -1.1017378757786669
# col:dist_O_3_x, score: -1.1118069824503172
# col:dist_F_0_x, score: -1.1076186864654831
# col:dist_F_1_x, score: -1.1115898268083153
# col:dist_H_0_y, score: -0.8146080550908773
# col:dist_H_1_y, score: -0.8412009160118243
# col:dist_H_2_y, score: -0.9513969965199055
# col:dist_H_3_y, score: -0.9884037918170833
# col:dist_H_4_y, score: -1.0224047439263262
# col:dist_C_0_y, score: -0.41267064275610726
# col:dist_C_1_y, score: -0.7774871136113107
# col:dist_C_2_y, score: -0.835178758618286
# col:dist_C_3_y, score: -0.9027308096053576
# col:dist_C_4_y, score: -0.9759099862474953
# col:dist_N_0_y, score: -0.6921831050269295
# col:dist_N_1_y, score: -1.0625930877776861
# col:dist_N_2_y, score: -1.1064270503653792
# col:dist_N_3_y, score: -1.110694360612388
# col:dist_N_4_y, score: -1.1119369347226895
# col:dist_O_0_y, score: -0.5910205217258511
# col:dist_O_1_y, score: -1.0121632930073539
# col:dist_O_2_y, score: -1.100628727536486
# col:dist_O_3_y, score: -1.111380664071045
# col:dist_F_0_y, score: -1.1087372562332958
# col:dist_F_1_y, score: -1.1116374752287301
# col:tda_max_radius, score: -1.0303144613657444
# col:tda_min_radius, score: -1.0899485625975283
# col:a1_degree, score: -0.9944191582560354
# col:a1_hybridization, score: -0.7031954104881082
# col:a1_inring, score: -1.0752656049500837
# col:a1_inring3, score: -0.9638019976880978
# col:a1_inring4, score: -0.7729617857797131
# col:a1_inring5, score: -1.022427996044764
# col:a1_inring6, score: -1.0860991453436493
# col:a1_inring7, score: -1.1050213848239594
# col:a1_inring8, score: -1.1117190519279385
# col:a1_nb_h, score: -1.1106708126793605
# col:a1_nb_o, score: -0.9145925038063942
# col:a1_nb_c, score: -1.107154174131835
# col:a1_nb_n, score: -1.0477775041454052
# col:a1_nb_na, score: -1.1105298834283648
# col:a0_nb_degree, score: -1.0448084231485264
# col:a0_nb_hybridization, score: -0.6898035872303758
# col:a0_nb_inring, score: -0.9426803824245817
# col:a0_nb_inring3, score: -0.9922531306151741
# col:a0_nb_inring4, score: -0.9754806906499682
# col:a0_nb_inring5, score: -1.0294217674122788
# col:a0_nb_inring6, score: -1.0968615069002594
# col:a0_nb_inring7, score: -1.1094205624604006
# col:a0_nb_inring8, score: -1.11182318218951
# col:a0_nb_nb_h, score: -1.0621324270079733
# col:a0_nb_nb_o, score: -0.7426925163477962
# col:a0_nb_nb_c, score: -1.052362791223244
# col:a0_nb_nb_n, score: -0.9322001522938755
# col:a0_nb_nb_na, score: -1.1120130623643119
# col:x_a0_nb, score: -1.1011612392795826
# col:y_a0_nb, score: -1.0820345169595973
# col:z_a0_nb, score: -1.1029266425879527
# col:a1_nb_degree, score: -1.0795293903569803
# col:a1_nb_hybridization, score: -1.0984172628106599
# col:a1_nb_inring, score: -1.1068737449712174
# col:a1_nb_inring3, score: -1.103653021426989
# col:a1_nb_inring4, score: -1.093193601661902
# col:a1_nb_inring5, score: -1.0948971070069284
# col:a1_nb_inring6, score: -1.1101884778162043
# col:a1_nb_inring7, score: -1.1112933022735452
# col:a1_nb_inring8, score: -1.1114351361676906
# col:a1_nb_nb_h, score: -1.096129059936689
# col:a1_nb_nb_o, score: -1.1044989414118294
# col:a1_nb_nb_c, score: -1.1041184666541632
# col:a1_nb_nb_n, score: -1.0855056193160928
# col:a1_nb_nb_na, score: -1.1120105275919865
# col:x_a1_nb, score: -1.095083463546088
# col:y_a1_nb, score: -1.07390355946317
# col:z_a1_nb, score: -1.0972085090788661
# col:dist_to_type_mean, score: -0.008194903762386407

# %%
result_df = pd.DataFrame(result_list)

# %%
result_df
# Out:
#                                       col     score
# 0          molecule_atom_index_0_dist_min -0.801699
# 1          molecule_atom_index_0_dist_max -0.835570
# 2          molecule_atom_index_1_dist_min -0.856842
# 3         molecule_atom_index_0_dist_mean -1.015187
# 4          molecule_atom_index_0_dist_std -1.064799
# 5                                    dist  0.597475
# 6                                abs_dist -1.048671
# 7                                     x_0 -1.100368
# 8                                     y_0 -1.082755
# 9                                     z_0 -1.101657
# 10                                    x_1 -1.094272
# 11                                    y_1 -1.063711
# 12                                    z_1 -1.100716
# 13         molecule_atom_index_1_dist_std -1.062099
# 14         molecule_atom_index_1_dist_max -0.937912
# 15        molecule_atom_index_1_dist_mean -1.058585
# 16    molecule_atom_index_0_dist_max_diff -0.798301
# 17     molecule_atom_index_0_dist_max_div -0.724557
# 18    molecule_atom_index_0_dist_std_diff -0.899956
# 19     molecule_atom_index_0_dist_std_div -0.795719
# 20                   atom_0_couples_count -1.061748
# 21     molecule_atom_index_0_dist_min_div -0.620997
# 22    molecule_atom_index_1_dist_std_diff -0.983166
# 23    molecule_atom_index_0_dist_mean_div -0.994993
# 24                   atom_1_couples_count -1.073836
# 25   molecule_atom_index_0_dist_mean_diff -0.882154
# 26                       molecule_couples -1.086649
# 27                           atom_index_1 -1.075261
# 28                     molecule_dist_mean -1.079688
# 29    molecule_atom_index_1_dist_max_diff -0.910659
# ..                                    ...       ...
# 157                         a0_nb_inring5 -1.029422
# 158                         a0_nb_inring6 -1.096862
# 159                         a0_nb_inring7 -1.109421
# 160                         a0_nb_inring8 -1.111823
# 161                            a0_nb_nb_h -1.062132
# 162                            a0_nb_nb_o -0.742693
# 163                            a0_nb_nb_c -1.052363
# 164                            a0_nb_nb_n -0.932200
# 165                           a0_nb_nb_na -1.112013
# 166                               x_a0_nb -1.101161
# 167                               y_a0_nb -1.082035
# 168                               z_a0_nb -1.102927
# 169                          a1_nb_degree -1.079529
# 170                   a1_nb_hybridization -1.098417
# 171                          a1_nb_inring -1.106874
# 172                         a1_nb_inring3 -1.103653
# 173                         a1_nb_inring4 -1.093194
# 174                         a1_nb_inring5 -1.094897
# 175                         a1_nb_inring6 -1.110188
# 176                         a1_nb_inring7 -1.111293
# 177                         a1_nb_inring8 -1.111435
# 178                            a1_nb_nb_h -1.096129
# 179                            a1_nb_nb_o -1.104499
# 180                            a1_nb_nb_c -1.104118
# 181                            a1_nb_nb_n -1.085506
# 182                           a1_nb_nb_na -1.112011
# 183                               x_a1_nb -1.095083
# 184                               y_a1_nb -1.073904
# 185                               z_a1_nb -1.097209
# 186                     dist_to_type_mean -0.008195
#
# [187 rows x 2 columns]

# %%
result_df.to_csv("./permutation_importance.csv")

# %%
print(1)
